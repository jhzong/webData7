# %% [markdown]
# # 옥션 tv검색 1~5페이지까지 웹스크랩핑
# # 후기 50이상, 구매 100이상, 가격1000000이상 출력
# # 이미지,상품,가격,평점,후기,구매 csv로 저장

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait # 대기툴
from selenium.webdriver.support import expected_conditions as EC # 대기툴
import requests
from bs4 import BeautifulSoup
import time
import os
import random
import csv
from selenium.webdriver.chrome.options import Options

# 상단 Chrome자동화 구문 제거
options = Options()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument("--disable-blink-features=AutomationControlled")
browser = webdriver.Chrome(options=options) # 창열기

# %%
for i in range(5):
    url=f'https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.5758486aGqwXNn&keyword=tv&p={i+1}'
    print(url)

# %%
# 옥션 페이지
url="https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.5758486aGqwXNn&keyword=tv&p=1"
browser=webdriver.Chrome()# 새창열기
browser.maximize_window()# 창화면 확대
browser.get(url)
time.sleep(1)

# %%
# data받기
soup=BeautifulSoup(browser.page_source,'lxml')# html소스 bs로 변경

section=soup.find_all('div',{'class':'section__module-wrap'})
print(section[1].find_all('div',{'class':'box__item-container'})[0].text)
# Out:
# 삼성전자상품명 삼성전자 TV렌탈 가전구독 모음전 전국무료설치/사은품증정월판매가17,100원기본설치비 무료의무약정기간 60개월사은품상담신청 3건판매자렌탈마루판매자평가정보
